# %%
import numpy as np
import matplotlib.pyplot as plt 
import os
# from prepare_data import prepare_input

# %%
max_iter =10000
size = 40

# %%
# #input ground truth

# algs={'M':1e-5,'A':1,'B':1,'C':1}
# keys=['Obj_list','runtime','distance']


# plt.figure()
# for key in keys:
#     for alg in algs:
#         #input A
        

#         output_folder = 'output/'+f'{size}/'+f'{max_iter}'
#         save_folder=os.path.join(output_folder,f'{alg}')
    
#         ep=algs[alg]
#         name=os.path.join(save_folder,f'{alg}_{key}_{ep}'+'.npy')
#         if os.path.exists(name):
#             key_value = np.load(name)
#         else:
#             print(f'{name} not exist')
#         plt.plot(key_value,label=f'{alg}')    


#     plt.ylabel(f'{key}')
#     plt.legend()
    
#     plt.yscale('log')
#     plt.show()

# %%
a=np.load('output/40/10000/A/runtime_0.1.npy')
len(a)
# Out:
# 9999

# %%
#input ground truth


algs={
    'M':[1e-5],
    'A':[10**i for i in range(-1,3)]}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        
        for ep in algs[alg]:

            output_folder = 'output/'+f'{size}/'+f'{max_iter}'
            save_folder=os.path.join(output_folder,f'{alg}')

            
            name=os.path.join(save_folder,f'{key}_{ep}'+'.npy')
            if os.path.exists(name):
                key_value = np.load(name)

            else:
                print(f'{name} not exist')
            
            plt.plot(key_value,label=f'{alg}-{ep}')    

    y_label = {'runtime': 'computation time', 'Obj_list':'objective value', 'distance': 'distance to optimal solution'}
    plt.ylabel(y_label[key])
    plt.legend(loc='upper right', bbox_to_anchor=(1, 1))

    
    plt.yscale('log')
    plt.show()

# %%
#input ground truth


algs={
    'M':[1e-5],
    'B':[10**i for i in range(-1,3)]}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        
        for ep in algs[alg]:

            output_folder = 'output/'+f'{size}/'+f'{max_iter}'
            save_folder=os.path.join(output_folder,f'{alg}')

            
            name=os.path.join(save_folder,f'{key}_{ep}'+'.npy')
            if os.path.exists(name):
                key_value = np.load(name)

            else:
                print(f'{name} not exist')
            plt.plot(key_value,label=f'{alg}-{ep}')    


    y_label = {'runtime': 'computation time', 'Obj_list':'objective value', 'distance': 'distance to optimal solution'}
    plt.ylabel(y_label[key])
    plt.legend(loc='upper right', bbox_to_anchor=(1, 1))
    
    plt.yscale('log')
    plt.show()

# %%
#input ground truth


algs={
    'M':[1e-5],
    'C':[10**i for i in range(-1,5)]}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        
        for ep in algs[alg]:

            output_folder = 'output/'+f'{size}/'+f'{max_iter}'
            save_folder=os.path.join(output_folder,f'{alg}')

            
            name=os.path.join(save_folder,f'{key}_{ep}'+'.npy')
            if os.path.exists(name):
                key_value = np.load(name)

            else:
                print(f'{name} not exist')
            plt.plot(key_value,label=f'{alg}-{ep}')    


    y_label = {'runtime': 'computation time', 'Obj_list':'objective value', 'distance': 'distance to optimal solution'}
    plt.ylabel(y_label[key])
    plt.legend(loc='upper right', bbox_to_anchor=(1, 1))
    
    plt.yscale('log')
    plt.show()

# %%
# algs = {'C':[10**i for i in range(-10,10) ]}
# keys=['runtime']
# for key in keys:
#     for alg in algs:
#         #input A
        
#         for ep in algs[alg]:

#             output_folder = 'output/'+f'{size}/'+f'{max_iter}'
#             save_folder=os.path.join(output_folder,f'{alg}')

            
#             name=os.path.join(save_folder,f'{key}_{ep}'+'.npy')
#             if os.path.exists(name):
#                 key_value = np.load(name)
#                 print (len(key_value))
#                 key_value = key_value[:10000]
#                 np.save(name,key_value)
#                 print(ep)

#             else:
#                 print(f'{name} not exist')
