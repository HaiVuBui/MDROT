# %%
import numpy as np
import matplotlib.pyplot as plt 
import os
# from prepare_data import prepare_input

# %%
max_iter =10000

# %%
#input ground truth

algs={'M':1e-5,'A':1,'B':1,'C':1}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        

        output_folder = 'output_40/'+'max_iter-'+f'{max_iter}'
        save_folder=os.path.join(output_folder,f'{alg}-{max_iter}')

        
    
        ep=algs[alg]
        name=os.path.join(save_folder,f'{alg}_{key}{ep}'+'.npy')
        if os.path.exists(name):
            key_value = np.load(name)
        else:
            print(f'{name} not exist')
        plt.plot(key_value,label=f'{alg}')    


    plt.ylabel(f'{key}')
    plt.legend()
    
    plt.yscale('log')
    plt.show()
# Out:
# output_40/max_iter-10000/C-10000/C_Obj_list1.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime1.npy not exist
# output_40/max_iter-10000/C-10000/C_distance1.npy not exist

# %%
#input ground truth


algs={'M':[-5],'A':range(-3,2)}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        
        for i in algs[alg]:
            ep=10**i
            output_folder = 'output_40/'+'max_iter-'+f'{max_iter}'
            save_folder=os.path.join(output_folder,f'{alg}-{max_iter}')

            
            name=os.path.join(save_folder,f'{alg}_{key}{ep}'+'.npy')
            if os.path.exists(name):
                key_value = np.load(name)

            else:
                print(f'{name} not exist')
            plt.plot(key_value,label=f'{alg}-{ep}')    


    plt.ylabel(f'{key}')
    plt.legend(loc='upper left', bbox_to_anchor=(-0.1, 1))
    
    plt.yscale('log')
    plt.show()

# %%
#input ground truth


algs={'M':[-5],'B':range(-1,4)}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        
        for i in algs[alg]:
            ep=10**i
            output_folder = 'output_40/'+'max_iter-'+f'{max_iter}'
            save_folder=os.path.join(output_folder,f'{alg}-{max_iter}')

            
            name=os.path.join(save_folder,f'{alg}_{key}{ep}'+'.npy')
            if os.path.exists(name):
                key_value = np.load(name)

            else:
                print(f'{name} not exist')
            plt.plot(key_value,label=f'{alg}-{ep}')    


    plt.ylabel(f'{key}')
    plt.legend(loc='upper left', bbox_to_anchor=(-0.1, 1))
    
    plt.yscale('log')
    plt.show()
# Out:
# output_40/max_iter-10000/B-10000/B_Obj_list100.npy not exist
# output_40/max_iter-10000/B-10000/B_Obj_list1000.npy not exist
# output_40/max_iter-10000/B-10000/B_runtime100.npy not exist
# output_40/max_iter-10000/B-10000/B_runtime1000.npy not exist
# output_40/max_iter-10000/B-10000/B_distance100.npy not exist
# output_40/max_iter-10000/B-10000/B_distance1000.npy not exist

# %%
#input ground truth


algs={'M':[-5],'C':range(-1,5)}
keys=['Obj_list','runtime','distance']


plt.figure()
for key in keys:
    for alg in algs:
        #input A
        
        for i in algs[alg]:
            ep=10**i
            output_folder = 'output_40/'+'max_iter-'+f'{max_iter}'
            save_folder=os.path.join(output_folder,f'{alg}-{max_iter}')

            
            name=os.path.join(save_folder,f'{alg}_{key}{ep}'+'.npy')
            if os.path.exists(name):
                key_value = np.load(name)

            else:
                print(f'{name} not exist')
            plt.plot(key_value,label=f'{alg}-{ep}')    


    plt.ylabel(f'{key}')
    plt.legend(loc='upper left', bbox_to_anchor=(-0.1, 1))
    
    plt.yscale('log')
    plt.show()
# Out:
# output_40/max_iter-10000/C-10000/C_Obj_list0.1.npy not exist
# output_40/max_iter-10000/C-10000/C_Obj_list1.npy not exist
# output_40/max_iter-10000/C-10000/C_Obj_list10.npy not exist
# output_40/max_iter-10000/C-10000/C_Obj_list100.npy not exist
# output_40/max_iter-10000/C-10000/C_Obj_list1000.npy not exist
# output_40/max_iter-10000/C-10000/C_Obj_list10000.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime0.1.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime1.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime10.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime100.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime1000.npy not exist
# output_40/max_iter-10000/C-10000/C_runtime10000.npy not exist
# output_40/max_iter-10000/C-10000/C_distance0.1.npy not exist
# output_40/max_iter-10000/C-10000/C_distance1.npy not exist
# output_40/max_iter-10000/C-10000/C_distance10.npy not exist
# output_40/max_iter-10000/C-10000/C_distance100.npy not exist
# output_40/max_iter-10000/C-10000/C_distance1000.npy not exist
# output_40/max_iter-10000/C-10000/C_distance10000.npy not exist
